# %% [markdown]
# # Data Analysis and Interpretation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\AYUB ALI\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r"C:\Users\AYUB ALI\Downloads\hrdataset.csv")

# %%
df
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 0     Female         0           No   Yes  Month-to-month      No    Yes   18
# 1     Female         0           No   Yes  Month-to-month      No    Yes   19
# 2       Male         0           No   Yes  Month-to-month     Yes     No   22
# 3     Female         1           No   Yes  Month-to-month     Yes    Yes   21
# 4       Male         0           No   Yes  Month-to-month     Yes    Yes   23
# ...      ...       ...          ...   ...             ...     ...    ...  ...
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
# ...

# %%
df.shape
# Out:
# (5000, 20)

# %% [markdown]
# Data have 5000 rows and 20 column

# %%
df.size
# Out:
# 100000

# %%
df.describe()
# Out:
#           Business          Age         Salary      Base_pay        Bonus  \
# count  5000.000000  5000.000000    5000.000000   4977.000000  5000.000000
# mean      0.160000    51.865000   99821.928553  40046.187707  4991.096428
# std       0.366643     8.560691   25376.961744  10135.686075  1268.848087
# min       0.000000    18.000000    5089.000000   2035.600000   254.450000
# 25%       0.000000    47.000000   83890.338980  33720.552420  4194.516950
# 50%       0.000000    52.000000  100579.378500  40282.016040  5028.968925
# 75%       0.000000    57.000000  116912.092475  46792.232410  5845.604624
# max       1.000000    88.000000  199970.740000  79988.296000  9998.537000
#
#         Unit_Price        Volume  openingbalance  closingbalance          low  \
# count  5000.000000  5.000000e+03     3524.000000     5000.000000  5000.000000
# mean     51.258522  6.761260e+06       43.922020       43.577828    43.034129
# ...

# %%
#filing empty cells of Total_sales with nan
df=df.replace(r'^\s*$', float(np.NaN), regex=True)

# %%
df.tail() #to check weather that values are replaced with nan or not
# Out:
#       Gender  Business Dependancies Calls            Type Billing Rating  Age  \
# 4995  Female         0           No   Yes  Month-to-month      No     No   72
# 4996    Male         0           No   Yes  Month-to-month     Yes     No   73
# 4997    Male         0           No   Yes  Month-to-month     Yes     No   74
# 4998    Male         1           No   Yes  Month-to-month     Yes    Yes   74
# 4999    Male         0          Yes   Yes        Two year     Yes     No   88
#
#          Salary   Base_pay     Bonus  Unit_Price   Volume  openingbalance  \
# 4995  180696.80  72278.720  9034.840  629.511067  3927000             NaN
# 4996  185685.90  74274.360  9284.295  627.841071  6031900             NaN
# 4997  192636.80  77054.720  9631.840  625.860033  7949400             NaN
# 4998  195970.70  78388.280  9798.535  629.510005  3908400             NaN
# 4999  199970.74  79988.296  9998.537  627.839984  6003300             NaN
#
# ...

# %%
df['Total_Sales'] = df['Total_Sales'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          5000 non-null   object
#  1   Business        5000 non-null   int64
#  2   Dependancies    5000 non-null   object
#  3   Calls           5000 non-null   object
#  4   Type            5000 non-null   object
#  5   Billing         5000 non-null   object
#  6   Rating          5000 non-null   object
#  7   Age             5000 non-null   int64
#  8   Salary          5000 non-null   float64
#  9   Base_pay        4977 non-null   float64
#  10  Bonus           5000 non-null   float64
#  11  Unit_Price      5000 non-null   float64
#  12  Volume          5000 non-null   int64
#  13  openingbalance  3524 non-null   float64
#  14  closingbalance  5000 non-null   float64
#  15  low             5000 non-null   float64
#  16  Unit_Sales      5000 non-null   float64
# ...

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# Gender               0
# Business             0
# Dependancies         0
# Calls                0
# Type                 0
# Billing              0
# Rating               0
# Age                  0
# Salary               0
# Base_pay            23
# Bonus                0
# Unit_Price           0
# Volume               0
# openingbalance    1476
# closingbalance       0
# low                  0
# Unit_Sales           0
# Total_Sales         16
# Months               0
# Education            0
# dtype: int64

# %%
df.isnull().sum() * 100 / len(df)
# Out:
# Gender             0.00
# Business           0.00
# Dependancies       0.00
# Calls              0.00
# Type               0.00
# Billing            0.00
# Rating             0.00
# Age                0.00
# Salary             0.00
# Base_pay           0.46
# Bonus              0.00
# Unit_Price         0.00
# Volume             0.00
# openingbalance    29.52
# closingbalance     0.00
# low                0.00
# Unit_Sales         0.00
# Total_Sales        0.32
# Months             0.00
# Education          0.00
# dtype: float64

# %%
from sklearn.impute import KNNImputer
x=df[['Base_pay','openingbalance','Total_Sales']]

#create an object
imputer= KNNImputer(n_neighbors=2)
#fit and transform the values
x=imputer.fit_transform(x)

# %%
df[['Base_pay','openingbalance','Total_Sales']]=pd.DataFrame(x, columns =['Base_pay','openingbalance','Total_Sales'])

# %%
df.isna().sum()
# Out:
# Gender            0
# Business          0
# Dependancies      0
# Calls             0
# Type              0
# Billing           0
# Rating            0
# Age               0
# Salary            0
# Base_pay          0
# Bonus             0
# Unit_Price        0
# Volume            0
# openingbalance    0
# closingbalance    0
# low               0
# Unit_Sales        0
# Total_Sales       0
# Months            0
# Education         0
# dtype: int64

# %% [markdown]
# # EDA

# %%
#cgecking the total employee education wise
degree_wise=df.Education.value_counts()
degree_wise
# Out:
# Education
# PG                     2979
# Graduation             1980
# Intermediate             27
# High School or less      14
# Name: count, dtype: int64

# %% [markdown]
# # we can see that 2979 employee have pg degree, 1980 have done Graduation, 27 people has done Intermediate ..... who are more educated.

# %%
Gender_wise=df.Gender.value_counts()
Gender_wise
# Out:
# Gender
# Male      2528
# Female    2472
# Name: count, dtype: int64

# %% [markdown]
# S number of male and female employes employess are almost equal

# %%
Rating_wise=df.Rating.value_counts()
Rating_wise
# Out:
# Rating
# No     3682
# Yes    1318
# Name: count, dtype: int64

# %%
call_wise=df.Calls.value_counts()
call_wise
# Out:
# Calls
# Yes    4539
# No      461
# Name: count, dtype: int64

# %%
Dependancies_wise=df.Dependancies.value_counts()
Dependancies_wise
# Out:
# Dependancies
# No     3524
# Yes    1476
# Name: count, dtype: int64

# %%
Age_wise=df.Age.value_counts()
Age_wise
# Out:
# Age
# 50    256
# 53    254
# 55    248
# 54    245
# 51    244
#      ...
# 78      2
# 80      1
# 82      1
# 85      1
# 79      1
# Name: count, Length: 65, dtype: int64

# %%
Type_wise=df.Type.value_counts()
Type_wise
# Out:
# Type
# Month-to-month    2777
# Two year          1195
# One year          1028
# Name: count, dtype: int64

# %%
Billing_wise=df.Billing.value_counts()
Billing_wise
# Out:
# Billing
# Yes    2956
# No     2044
# Name: count, dtype: int64

# %%
Salary_wise=df.Salary.value_counts()
Salary_wise
# Out:
# Salary
# 5089.00000      1
# 111156.23070    1
# 111244.88770    1
# 111226.64990    1
# 111215.52600    1
#                ..
# 90267.02079     1
# 90261.41699     1
# 90246.38343     1
# 90215.66586     1
# 199970.74000    1
# Name: count, Length: 5000, dtype: int64

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(10, 10))
sns.histplot(data=df, x="Salary", kde=True, color="red", ax=axs[0, 0])
sns.histplot(data=df, x="Base_pay", kde=True, color="olive", ax=axs[0, 1])
sns.histplot(data=df, x="Bonus", kde=True, color="gold", ax=axs[1, 0])
sns.histplot(data=df, x="Age", kde=True, color="black", ax=axs[1, 1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
sns.histplot(data=df, x="low", kde=True, color="red", ax=axs[0])
sns.histplot(data=df, x="Total_Sales", kde=True, color="Navy", ax=axs[1])
plt.show()

# %%
#Relationship between Categorical Variables and the Dependent variable

# %%
#Looking the categorical columns
df.select_dtypes(include=['object']).columns.tolist()
# Out:
# ['Gender', 'Dependancies', 'Calls', 'Type', 'Billing', 'Rating', 'Education']

# %% [markdown]
# We have above categorical columns now we are going  too see this variables relationship with dependent variable which is salary of employees

# %%
plt.figure(figsize=(9,8)) #size of the figure
sns.boxplot(data=df,x="Gender", y="Salary", color="Red") #plotting the box plot for Salary vs gender. 
plt.title("Salary vs Gender") #plot title.
# Out:
# Text(0.5, 1.0, 'Salary vs Gender')

# %%
plt.figure(figsize=(9,8)) #size of the figure
sns.boxplot(data=df,x="Dependancies", y="Salary", color="Blue") #plotting the box plot for Salary vs gender. 
plt.title("Salary vs Dependancies") #plot title.
# Out:
# Text(0.5, 1.0, 'Salary vs Dependancies')

# %%
plt.figure(figsize=(9,8)) 
sns.boxplot(data=df,x="Calls", y="Salary", color="SkyBlue") 
plt.title("Salary vs Calls")
# Out:
# Text(0.5, 1.0, 'Salary vs Calls')

# %%
plt.figure(figsize=(9,8)) 
sns.boxplot(data=df,x="Type", y="Salary", color="Yellow") 
plt.title("Salary vs Type")
# Out:
# Text(0.5, 1.0, 'Salary vs Type')

# %%
plt.figure(figsize=(9,8)) 
sns.boxplot(data=df,x="Billing", y="Salary", color="Red") 
plt.title("Salary vs Billing")
# Out:
# Text(0.5, 1.0, 'Salary vs Billing')

# %%
plt.figure(figsize=(9,8)) 
sns.boxplot(data=df,x="Rating", y="Salary", color="Red") 
plt.title("Salary vs rating")
# Out:
# Text(0.5, 1.0, 'Salary vs rating')

# %%
plt.figure(figsize=(9,8)) 
sns.boxplot(data=df,x="Education", y="Salary", color="Red") 
plt.title("Salary vs Education")
# Out:
# Text(0.5, 1.0, 'Salary vs Education')

# %% [markdown]
# # Scatter plot to see relationship between numerical data

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Base_pay', fontsize=15)
plt.ylabel('salary', fontsize=15)
plt.title('Base_pay vs salary', fontsize=15)
sns.scatterplot (x=df[ 'Base_pay'],y=df['Salary'], color='black') 
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Bonus', fontsize=15)
plt.ylabel('salary', fontsize=15)
plt.title('Bonus vs salary', fontsize=15)
sns.scatterplot (x=df[ 'Bonus'],y=df['Salary'], color='black') 
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('Unit_Price', fontsize=15)
plt.ylabel('salary', fontsize=15)
plt.title('Unit_Price vs salary', fontsize=15)
sns.scatterplot (x=df[ 'Unit_Price'],y=df['Salary'], color='black') 
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Volume', fontsize=20)
plt.ylabel('salary', fontsize=20)
plt.title('Volume vs salary', fontsize=20)
sns.scatterplot (x=df[ 'Volume'],y=df['Salary'], color='black') 
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('openingbalance', fontsize=15)
plt.ylabel('salary', fontsize=15)
plt.title('openingbalance vs salary', fontsize=15)
sns.scatterplot (x=df[ 'openingbalance'],y=df['Salary'], color='blue') 
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Age', fontsize=20)
plt.ylabel('salary', fontsize=20)
plt.title('Age vs salary', fontsize=20)
sns.scatterplot (x=df[ 'Age'],y=df['Salary'], color='green') 
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.xlabel('closingbalance', fontsize=15)
plt.ylabel('salary', fontsize=15)
plt.title('closingbalance vs salary', fontsize=15)
sns.scatterplot (x=df[ 'closingbalance'],y=df['Salary'], color='purple') 
plt.show()

# %% [markdown]
# # Data Cleaning and Justification

# %%
plt.figure(figsize=(9,7)) #size of the figure
figure=df.boxplot(column="Age") #box plot of the age.

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Salary")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Base_pay")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Bonus")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Unit_Price")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="openingbalance")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="closingbalance")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Unit_Sales")

# %%
plt.figure(figsize=(9,7))
figure=df.boxplot(column="Total_Sales")

# %% [markdown]
# # Feature engineering

# %%
df3_numeric = df.select_dtypes(include='number')
df3_numeric.corr(method='spearman')*100
# Out:
#                   Business         Age      Salary    Base_pay       Bonus  \
# Business        100.000000   -0.843515   -1.840271   -1.848851   -1.840271
# Age              -0.843515  100.000000   20.228180   20.212073   20.228180
# Salary           -1.840271   20.228180  100.000000   99.997589  100.000000
# Base_pay         -1.848851   20.212073   99.997589  100.000000   99.997589
# Bonus            -1.840271   20.228180  100.000000   99.997589  100.000000
# Unit_Price       -1.948029   12.826637   81.171311   81.168113   81.171311
# Volume           -0.219201   -3.934477  -39.048779  -39.042656  -39.048779
# openingbalance   -2.253152   -5.291931   45.346909   45.285139   45.346909
# closingbalance   -0.748502   44.098882   34.649833   34.640860   34.649833
# low              -1.810280   20.203950   99.985870   99.983405   99.985870
# Unit_Sales       -1.836288   20.226808   99.999741   99.997324   99.999741
# ...

# %%
#Dropping the non-required variables
dff = df.drop(columns=['Gender', 'Business', 'Dependancies', 'Calls', 'Type', 'Billing', 
                       'Rating', 'Base_pay', 'Unit_Price', 'low', 'Unit_Sales', 
                       'Total_Sales', 'openingbalance', 'closingbalance','Volume','Bonus'])
dff.head()
# Out:
#    Age   Salary  Months            Education
# 0   18  5089.00       0  High School or less
# 1   19  5698.12       0  High School or less
# 2   22  5896.65       0  High School or less
# 3   21  6125.12       0  High School or less
# 4   23  6245.00       1  High School or less

# %%
dff['Education']=dff['Education'].map({'High School or less' : 0, 'Intermediate' : 1, 'Graduation' : 2, 'PG': 3})

# %%
dff.head()
# Out:
#    Age   Salary  Months  Education
# 0   18  5089.00       0          0
# 1   19  5698.12       0          0
# 2   22  5896.65       0          0
# 3   21  6125.12       0          0
# 4   23  6245.00       1          0

# %% [markdown]
# # Handaling Outliers

# %%
Q1=dff.quantile (0.25).round(3) # taking lower quantile into Q2 
Q3 =dff.quantile (0.75).round(3) # taking upper quarantile to Q3
IQR = Q3 - Q1 #calculating inter quantile range 
print(IQR) #printing quatile range
# Out:
# Age             10.000
# Salary       33021.753
# Months          47.000
# Education        1.000
# dtype: float64

# %%
dfout = dff[~((dff < (Q1- 1.5 * IQR))| (dff > (Q3+ 1.5 * IQR))).any(axis=1)]
dfout.shape
# Out:
# (4833, 4)

# %%
# sanity check

# %%
sns.boxplot(x=dfout['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.histplot(data=dff, x='Age', kde=True, color='Black')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot(x=dfout['Salary'])
# Out:
# <Axes: xlabel='Salary'>

# %%
sns.histplot(data=dff, x='Salary', kde=True, color='Black')
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
x=dfout.drop(['Salary'], axis=1)

# %%
x
# Out:
#       Age  Months  Education
# 66     38       1          2
# 67     38       1          2
# 68     38       1          2
# 69     38       1          2
# 70     38       1          2
# ...   ...     ...        ...
# 4984   70      72          3
# 4985   70      72          3
# 4986   70      72          3
# 4987   70      72          3
# 4988   70      72          3
#
# [4833 rows x 3 columns]

# %%
y = dfout['Salary']

# %%
y
# Out:
# 66       34852.95000
# 67       36258.40251
# 68       36966.16345
# 69       38048.29227
# 70       38583.98515
#             ...
# 4984    164641.10960
# 4985    164871.98410
# 4986    165009.36340
# 4987    165120.62820
# 4988    165132.48590
# Name: Salary, Length: 4833, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state=0)

# %%
x_train
# Out:
#       Age  Months  Education
# 638    53      27          3
# 295    47       8          2
# 2752   70      18          2
# 152    43       2          3
# 506    51      18          3
# ...   ...     ...        ...
# 1099   65      65          3
# 3400   47      35          3
# 1755   50       2          2
# 2709   67      17          2
# 2855   45      21          2
#
# [3383 rows x 3 columns]

# %%
y_train
# Out:
# 638      73104.89109
# 295      60166.17512
# 2752    103582.25920
# 152      52130.15956
# 506      68768.08000
#             ...
# 1099     81745.03646
# 3400    111957.91860
# 1755     91558.64081
# 2709    103167.12950
# 2855    104886.47850
# Name: Salary, Length: 3383, dtype: float64

# %%
x_test
# Out:
#       Age  Months  Education
# 586    52      23          3
# 817    56      42          2
# 3244   38      30          2
# 3451   50      37          2
# 4062   53      54          3
# ...   ...     ...        ...
# 1054   63      62          2
# 1128   69      66          3
# 3171   63      29          3
# 3564   53      40          2
# 4707   55      70          3
#
# [1450 rows x 3 columns]

# %%
y_test
# Out:
# 586      71451.01116
# 817      76852.76155
# 3244    109978.73080
# 3451    112718.10590
# 4062    121397.91430
#             ...
# 1054     80896.99559
# 1128     82125.82874
# 3171    108858.94230
# 3564    114435.39900
# 4707    137586.82350
# Name: Salary, Length: 1450, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

x_train = sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.10007538, -0.22256978,  0.80139442],
#        [-0.69094098, -0.99658468, -1.24782502],
#        [ 2.34128841, -0.58920841, -1.24782502],
#        ...,
#        [-0.2954328 , -1.24101044, -1.24782502],
#        [ 1.94578022, -0.62994604, -1.24782502],
#        [-0.95461311, -0.46699553, -1.24782502]])

# %%
x_test
# Out:
# array([[-0.03176068, -0.38552028,  0.80139442],
#        [ 0.49558356,  0.38849462, -1.24782502],
#        [-1.87746553, -0.1003569 , -1.24782502],
#        ...,
#        [ 1.41843598, -0.14109452,  0.80139442],
#        [ 0.10007538,  0.30701937, -1.24782502],
#        [ 0.3637475 ,  1.52914816,  0.80139442]])

# %%
#Importing DecisionTreeRegressor
from sklearn.tree import DecisionTreeRegressor
#CalLing DecisionTreeRegressor with max depth as 3 and calling it to dt.
dt= DecisionTreeRegressor (max_depth=3)

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
# Score of train model
print(dt.score(x_train, y_train))
#score of test model.
print(dt. score(x_test, y_test))
# Out:
# 0.538040809781262
# 0.5518724111657196

# %%
y_pred=dt.predict(x_test)

# %%
print(y_pred)
# Out:
# [ 95884.88548321 104773.81651795  95884.88548321 ... 100748.97172555
#  104773.81651795 133352.00490166]

# %%
#Importing metrices from sklearn Library
from sklearn import metrics
#Metrix gives r2 score to cross verify accuracy of model

# %%
#cheking the r2_score to y_test,y_predict to predict the accuracy. 
r_square=metrics.r2_score(y_test, y_pred)
print('R-square error for decision tree regressor is:', round(100*(r_square),3))
# Out:
# R-square error for decision tree regressor is: 55.187

# %%
#importing Random forest regressor from sklearn.ensemble and it to fr with random state 5 and fitting
from sklearn.ensemble import RandomForestRegressor
#importing metrices from sklearn Library 
from sklearn import metrics
rfr=RandomForestRegressor (random_state=5)
rfr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=5)

# %%
y1_pred= rfr.predict(x_test)

# %%
from sklearn import metrics
import numpy as np

# Assuming y_test and y1_pred are already defined

# Calculate and print performance metrics
mae = metrics.mean_absolute_error(y_test, y1_pred)
mse = metrics.mean_squared_error(y_test, y1_pred)
rmse = np.sqrt(mse)

# Ensure no division by zero for MAPE
# Use np.where to handle potential zero values in y_test
mape = np.mean(np.abs((y_test - y1_pred) / np.where(y_test != 0, np.abs(y_test), 1)))
mape_percentage = round(mape * 100, 2)
accuracy = round(100 * (1 - mape), 2)

print('Mean Absolute Error (MAE):', mae)
print('Mean Squared Error (MSE):', mse)
print('Root Mean Squared Error (RMSE):', rmse)
print('Mean Absolute Percentage Error (MAPE):', mape_percentage)
print('Accuracy:',accuracy)
# Out:
# Mean Absolute Error (MAE): 488.62538824197225
# Mean Squared Error (MSE): 7720163.246925443
# Root Mean Squared Error (RMSE): 2778.5181746617104
# Mean Absolute Percentage Error (MAPE): 0.6
# Accuracy: 99.4

# %%
#Importing RandomForestRegressor from skLearn.ensemble.
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=7)
# here we choose 7 trees onLy
rf. fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=7)

# %%
#Applying score to x_train, y_train.
rf. score(x_train, y_train)
# Out:
# 0.9929707654180395

# %%
#Applying score to x_test, y_test.
rf. score(x_test, y_test)
# Out:
# 0.9844445468611889

# %% [markdown]
# # Linear Regresion modeel

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#Loading Linear regression model 
reg_model=LinearRegression()

# %%
reg_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#Model evaluation for training set
y_predict = reg_model.predict(x_train)

# %%
rmse = (np.sqrt(mean_squared_error(y_train,y_predict)))
print(rmse)
from sklearn.metrics import r2_score
r2_score(y_train,y_predict)
# Out:
# 18034.61523642435
# 0.4022502524341208

# %%
y_testpredict = reg_model.predict(x_test)

# %%
r2=r2_score(y_test,y_testpredict)
r2
# Out:
# 0.4304934525652817

# %%
pip install xgboost
# Out:
# ...
#
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/e2/7b/8c1b410cd0604cee9a167a19f7e1746f5b92ae7d02ad574ab560b73c5a48/xgboost-2.1.1-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 325.1 kB/s eta 0:06:25
#    ---------------------------------------- 0.0/124.9 MB 279.3 kB/s eta 0:07:28
#    ---------------------------------------- 0.1/124.9 MB 326.1 kB/s eta 0:06:23
#    ---------------------------------------- 0.1/124.9 MB 326.1 kB/s eta 0:06:23
#    ---------------------------------------- 0.1/124.9 MB 409.6 kB/s eta 0:05:05
#    ---------------------------------------- 0.1/124.9 MB 409.6 kB/s eta 0:05:05
# ...

# %%
from sklearn.metrics import mean_absolute_error
import xgboost as xgb

# Create and train the XGBoost model
model_xgb = xgb.XGBRegressor()
model_xgb.fit(x_train, y_train)

# Make predictions
y_pred_xgb = model_xgb.predict(x_test)

# Calculate performance metrics
mae_xgb = mean_absolute_error(y_test,y_pred_xgb)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mse_xgb)
mape_xgb = np.mean(np.abs((y_test - y_pred_xgb) / np.abs(y_test)))
accuracy_xgb = 100 * (1 - mape_xgb)

# Print the performance metrics for XGBoost
print('XGBoost Metrics:')
print('Mean Absolute Error (MAE):', mae_xgb)
print('Mean Squared Error (MSE):', mse_xgb)
print('Root Mean Squared Error (RMSE):', rmse_xgb)
print('Mean Absolute Percentage Error (MAPE):', round(mape_xgb * 100, 2))
print('Accuracy:', round(accuracy_xgb, 2))
# Out:
# XGBoost Metrics:
# Mean Absolute Error (MAE): 497.4993526896551
# Mean Squared Error (MSE): 8010670.475544639
# Root Mean Squared Error (RMSE): 2830.312787581019
# Mean Absolute Percentage Error (MAPE): 0.6
# Accuracy: 99.4

# %%
model_xgb = xgb.XGBRegressor(objective='reg:squarederror', random_state=42)

# Define ShuffleSplit cross-validation
ssplit = ShuffleSplit(n_splits=10, test_size=0.3)

# Perform cross-validation
results_xgb = cross_val_score(model_xgb,x,y,cv=ssplit)

# Print results for each fold
print("Cross-validation results for each fold:")
print(results_xgb)

# Print mean accuracy across all folds
print("\nMean Cross-validation Accuracy:", np.mean(results_xgb))
# Out:
# Cross-validation results for each fold:
# [0.98612693 0.97902368 0.9921811  0.99227066 0.98530112 0.98610985
#  0.99104292 0.99036886 0.98603828 0.99361827]
#
# Mean Cross-validation Accuracy: 0.9882081685741717

# %%
import pickle
from xgboost import XGBRegressor

# Example: Train a model (XGBoost Regressor as an example) 
model_xgb = XGBRegressor()
model_xgb.fit(x_train, y_train)

# Save the trained model to a file using pickle
with open('hr.pkl', 'wb') as file:
  pickle.dump(model_xgb, file)
print("Model saved successfully.")
# Out:
# Model saved successfully.

# %%
with open('schar.pkl' , 'wb') as scaler_file:
    pickle.dump(sc, scaler_file)

# %%
import tkinter as tk
import pickle
import numpy as np

with open('hr.pkl','rb') as model_file:
    model = pickle.load(model_file)

# %%
# Define the content of the updated Streamlit script
streamlit_code = """
import streamlit as st
import pickle
import numpy as np

# Load the trained XGBoost model and scaler
with open('hr.pkl', 'rb') as model_file:
    model = pickle.load(model_file)

with open('schr.pkl', 'rb') as scaler_file:
    scaler = pickle.load(scaler_file)

# Create the web app
st.title('Salary Prediction App')

# Input fields
age = st.number_input('Age', min_value=0, max_value=120, value=30)
education = st.selectbox('Education Level', ['High School or less', 'Intermediate', 'Graduation', 'PG'])
experience_months = st.number_input('Months of Experience', min_value=0, max_value=600, value=60)  # Assuming max experience is 50 years

# Convert education to numeric encoding
education_mapping = {'High School or less': 0, 'Intermediate': 1, 'Graduation': 2, 'PG': 3}
education_encoded = education_mapping[education]

# Prepare the feature vector
features = np.array([[age, education_encoded, experience_months]], dtype=np.float64)

# Scale the features
features_scaled = scaler.transform(features)

# Predict salary
predicted_salary = model.predict(features_scaled)

# Display the result
st.write(f"Predicted Salary: ${predicted_salary[0]:,.2f}")
"""

# Specify the file path where the hrapp.py file will be saved
file_path = 'hrapp.py'

# Write the content to the file
with open(file_path, 'w') as file:
    file.write(streamlit_code)

print(f"File '{file_path}' has been saved.")
# Out:
# File 'hrapp.py' has been saved.

# %% [markdown]
# # Step 8 : Cross-validation

# %%
# Cross validation for our model
from sklearn.model_selection import ShuffleSplit
model=LinearRegression()
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.37720055 0.41698649 0.42664965 0.40327832 0.42349244 0.44077789
#  0.41395893 0.39689619 0.40683607 0.43561788]
# 0.41416944088822427

# %%
# Cross validation for our model
from sklearn.model_selection import ShuffleSplit
model=DecisionTreeRegressor(max_depth=3)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.54297196 0.53323987 0.54527758 0.55341859 0.53099464 0.54081339
#  0.50928397 0.53390835 0.52152937 0.58896682]
# 0.5400404546557434

# %%
# Cross validation for our model
from sklearn.model_selection import ShuffleSplit
model=RandomForestRegressor(random_state=5)
ssplit=ShuffleSplit(n_splits=10,test_size=0.30)
from sklearn.model_selection import cross_val_score
results=cross_val_score(model,x,y,cv=ssplit)
print(results)
print(np.mean(results))
# Out:
# [0.99373244 0.98799722 0.99108767 0.99185815 0.99480066 0.99092189
#  0.99016714 0.98963211 0.9899381  0.98994436]
# 0.9910079729699666
